# %% [markdown]
# # Webscraping Data from Amazon
#
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites. The web scraping software may directly access the World Wide Web using the Hypertext Transfer Protocol or a web browser.
#
# While web scraping can be done manually by a software user, the term typically refers to automated processes implemented using a bot or web crawler. It is a form of copying in which specific data is gathered and copied from the web, typically into a central local database or spreadsheet, for later retrieval or analysis.
#
# We would be using few python libraries for this purpose which are :-
#
# - BeautifulSoup
# - Requests
# - Pandas
#
# The website we are going to be scraping is https://www.amazon.in/gp/bestsellers/luggage.

# %%
#Importing the libraries 
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# Using the request library, what we are doing is sending request to the server to retrieve the information from the HTML page essentially and using the BeautifulSoup, we are able to parse the data to see the data clearly.
#
# BeautifulSoup is a powerful and useful library that gives many methods to navigate through the HTML page in order to get to the data the user is looking for.

# %%
request = requests.get('https://www.amazon.in/gp/bestsellers/luggage')
soup = BeautifulSoup(request.text,'html.parser')

# %% [markdown]
# In the cell below we have imported all the data that has the `div` class and we are only pulling in the text data. We later on created a variable Product that is essentially a blank list and appending all the text data to the Product list and removing any unwanted newlines or special characters by using a FOR loop.

# %%
xyz = soup.find('div', text = "")

# %%
product = xyz.find_all('div', class_='p13n-sc-truncate p13n-sc-line-clamp-2')

# %%
Product = []
for prod in product:
    Product.append(prod.text.strip())
    print(prod.text.strip())
# Out:
# NAPA HIDE Black Leather Wallet for Men
# WILDHORN® Carter Leather Wallet for Men (Black Croco)
# Storite PU Leather 9 Slot Vertical Credit Debit Card Holder Money Wallet Zipper Coin Purse for Men Women - Chocolate Brown
# GLUN Bolt Electronic Portable Fishing Hook Type Digital LED Screen Luggage Weighing Scale, 50 kg/110 Lb (Black)
# URBAN FOREST Black Leather Men's Card Holder With Pen Combo (UBF126BLK10208)
# M MEDLER Epoch Nylon 55 litres Waterproof Strolley Duffle Bag- 2 Wheels - Luggage Bag - (Navy Blue)
# WildHorn® RFID Protected Genuine High Quality Leather Wallet for Men (Black MATT)
# Trajectory Men's and Women's Neck Pillow Travel headrest Accessory in Black with Plane Flight Bus and Office (Black)
# American Tourister Casual Backpack
# Urban Forest Oliver Black RFID Blocking Leather Wallet for Men
# GoTrippin Metal Luggage Weighing Scale Digital (Silver_ELS)
# SAFARI 15 Ltrs Sea Blue Casual/School/College Backpack (DAYPACKNEO15CBSEB) & SAFARI 15 Ltrs Cherry Red Casual/School/College Backpack (DAYPACKNEO15CBCRE)
# Priority Disney Princess Belle 25 litres Yellow & Pink Polyester School Bag | Casual Bags | for Girls, Kids Backpack (Fairy 007)
# Napa Hide India Leather Men's Wallet (Black)
# Bulfyss Electronic 50Kgs Digital Luggage Weighing Scale (1 Year Warranty)
# DZert Kids School Bag Soft Plush Backpacks Cartoon Boys Girls Baby (2-5 Years)
# Hornbull Denial Aqua Blue Mens Leather Wallet – Premium Quality Leather Wallet for Mens & RFID Blocking Genuine Leather Mens Wallet
# DZert Kids School Bag Soft Plush Backpacks Cartoon Boys Girls Baby (2-5 Years)
# FASNO Combo bagpacks, Kids Bag , Plush Bags , School Bags for Kid Girl/boy.

# %% [markdown]
# We have on created a variable Price that is essentially a blank list and appending all the text data to the Price list and removing any unwanted newlines or special characters by using a `for loop`.

# %%
price = xyz.find_all('a', class_ = 'a-link-normal a-text-normal')

# %%
Price = []
for pri in price:
    Price.append(pri.text.strip().replace("₹", ""))
    print(pri.text.strip().replace("₹", ""))
# Out:
# 320.00 - 640.00
# 407.00 - 2,099.00
# 449.00 - 849.00
# 299.00
# 455.00 - 699.00
# 569.00 - 640.00
# 299.00 - 899.00
# 298.00 - 598.00
# 1,099.00 - 2,300.00
# 455.00 - 699.00
# 790.00
# 295.00 - 658.00
# 364.00 - 475.00
# 320.00 - 3,999.00
# 499.00
# 219.00 - 303.00
# 299.00 - 930.00
# 199.00 - 503.00
# 2,969.00 - 8,630.00
# 449.00 - 949.00
# 339.00 - 369.00
# 1,399.00
# 495.00 - 499.00
# 195.00 - 999.00
# 899.00
# 3,699.00 - 7,098.00
# 799.00 - 899.00
# 174.00 - 299.00
# 322.00 - 619.00
# 305.00
# 269.00 - 949.00
# 1 offer from 449.00
# 366.00 - 431.00
# 337.00
# 398.00 - 698.00
# 1,399.00
# 449.00
# 357.00 - 359.00
# 702.00 - 867.00
# 497.00 - 1,409.00
# 449.00 - 899.00
# 261.00 - 711.00
# 170.00 - 282.00
# 395.00 - 495.00
# 163.00
# 940.00 - 1,945.00
# 359.00 - 718.00
# 3,599.00
# 2,759.00
# 229.00 - 459.00

# %% [markdown]
# Let's go ahead and pull out some more data that may be useful. We are going to pulling out
#
# - Product Rating given by the users
# - How many people have rated the product?
#
# We will follow the same process and then store the data in either `CSV` or `dataframe` as per our requirements.

# %%
rating = xyz.find_all('span', class_ = 'a-icon-alt')

# %%
Rating = []
for rate in rating:
    Rating.append(rate.text[0:3])
    print(rate.text[0:3])
# Out:
# 4.0
# 4.0
# 4.1
# 3.9
# 4.3
# 3.6
# 4.0
# 3.9
# 4.1
# 4.3
# 4.4
# 4.0
# 3.9
# 4.1
# 4.1
# 3.8
# 4.3
# 3.7
# 4.2
# 4.0
# 4.6
# 4.0
# 4.1
# 3.9
# 4.3
# 4.2
# 4.2
# 3.8
# 4.2
# 3.9
# 4.0
# 4.1
# 4.1
# 4.2
# 4.0
# 4.0
# 4.4
# 4.3
# 4.0
# 4.1
# 4.1
# 4.5
# 4.0
# 4.3
# 3.9
# 4.0
# 4.1
# 4.3
# 4.2
# 3.9

# %%
reviewercount = xyz.find_all('div', class_ = 'a-icon-row')

# %%
RatingCount = []
for reviewer in reviewercount:
    RatingCount.append(reviewer.text[20:].replace("\n", ""))
    print(reviewer.text[20:].replace("\n", ""))
# Out:
# 20,223
# 15,736
# 3,010
# 11,063
# 28,149
# 14,004
# 22,272
# 4,530
# 33,966
# 5,388
# 5,125
# 10,370
# 6,778
# 7,491
# 4,328
# 2,537
# 5,090
# 5,670
# 8,122
# 8,285
# 325
# 4,471
# 6,938
# 2,766
# 2,052
# 5,344
# 3,744
# 4,481
# 2,632
# 1,877
# 5,323
# 1,593
# 1,320
# 532
# 4,158
# 451
# 2,229
# 2,746
# 5,707
# 3,719
# 2,111
# 696
# 381
# 662
# 1,212
# 943
# 6,691
# 4,047
# 2,485
# 715

# %% [markdown]
# Putting all the information into a single dataframe here. VOILA!!!

# %%
df = pd.DataFrame({'Product': Product,'Price (INR)': Price, 'Rating' : Rating, 'Count' : RatingCount})
df
# Out:
#                                               Product                Price  \
# 0              NAPA HIDE Black Leather Wallet for Men      320.00 - 640.00
# 1   WILDHORN® Carter Leather Wallet for Men (Black...    407.00 - 2,099.00
# 2   Storite PU Leather 9 Slot Vertical Credit Debi...      449.00 - 849.00
# 3   GLUN Bolt Electronic Portable Fishing Hook Typ...               299.00
# 4   URBAN FOREST Black Leather Men's Card Holder W...      455.00 - 699.00
# 5   M MEDLER Epoch Nylon 55 litres Waterproof Stro...      569.00 - 640.00
# 6   WildHorn® RFID Protected Genuine High Quality ...      299.00 - 899.00
# 7   Trajectory Men's and Women's Neck Pillow Trave...      298.00 - 598.00
# 8                  American Tourister Casual Backpack  1,099.00 - 2,300.00
# 9   Urban Forest Oliver Black RFID Blocking Leathe...      455.00 - 699.00
# 10  GoTrippin Metal Luggage Weighing Scale Digital...               790.00
# 11  SAFARI 15 Ltrs Sea Blue Casual/School/College ...      295.00 - 658.00
# 12  Priority Disney Princess Belle 25 litres Yello...      364.00 - 475.00
# 13       Napa Hide India Leather Men's Wallet (Black)    320.00 - 3,999.00
# 14  Bulfyss Electronic 50Kgs Digital Luggage Weigh...               499.00
# 15  DZert Kids School Bag Soft Plush Backpacks Car...      219.00 - 303.00
# 16  Hornbull Denial Aqua Blue Mens Leather Wallet ...      299.00 - 930.00
# 17  DZert Kids School Bag Soft Plush Backpacks Car...      199.00 - 503.00
# 18  Skybags Trooper 55 Cms Polycarbonate Blue Hard...  2,969.00 - 8,630.00
# 19  Hornbull Gift Hamper for Men | Navy Wallet and...      449.00 - 949.00
# 20  Shoeshine Pack of 12 Beige Shoe Bag Portable S...      339.00 - 369.00
# 21  Safari ARC Polyester 55 cms Black Travel Duffl...             1,399.00
# 22  AL FASCINO Stylish RFID Protected Genuine Leat...      495.00 - 499.00
# 23  Kraptick Men and Women Slim Leather Wallet Car...      195.00 - 999.00
# 24  Fur Jaden Black Textured Leatherette Weekender...               899.00
# 25  American Tourister Ivy Polypropylene 68 cms Bl...  3,699.00 - 7,098.00
# 26  Fur Jaden 55 LTR Rucksack Travel Backpack Bag ...      799.00 - 899.00
# 27  GEAR Black and Orange 49 cms Casual Backpack (...      174.00 - 299.00
# 28               Nivia Deflate Round - 01 Bag (Black)      322.00 - 619.00
# 29             DEIN KLEIDER Men's Nylon Messenger Bag               305.00
# 30  Storite 6 Slots RFID Blocking Metal Credit Car...      269.00 - 949.00
# 31  LONDON ALLEY Black Leather Men's RFID Blocking...  1 offer from 449.00
# 32  HAMMONDS FLYCATCHER Blue Leather Men's RFID Wa...      366.00 - 431.00
# 33  ALSU Women's Black Hand Clutch Wallet Purse(LD...               337.00
# 34  Trajectory Neck Pillow with Sleeping Eye mask ...      398.00 - 698.00
# 35  Safari ARC Polyester 65 cms Blue Travel Duffle...             1,399.00
# 36  FATMUG Polyester & Fabric Toiletry Bag (Dark G...               449.00
# 37  Sfane Polyester Duffle/Shoulder/Gym Bag for Me...      357.00 - 359.00
# 38  Priority ARC 51 cms Aqua Blue 2 Wheel Duffle T...      702.00 - 867.00
# 39  Urban Forest Blue Leather Wallet & Premium Key...    497.00 - 1,409.00
# 40  WildHorn® RFID Protected Genuine High Quality ...      449.00 - 899.00
# 41  Kuber Industries 6 Piece Non Woven Travel Shoe...      261.00 - 711.00
# 42             TnW Beige Leather Men's Wallet (tnw90)      170.00 - 282.00
# 43  Trajectory Passport Holder travel Organizer Po...      395.00 - 495.00
# 44  Mist Marvel Avengers Infinity War Thor Axe-Ham...               163.00
# 45  Lavie Sport Lino Cabin Size 53 cms Wheel Duffe...    940.00 - 1,945.00
# 46  SAFARI 15 Ltrs Denim Blue Casual/School/Colleg...      359.00 - 718.00
# 47  Safari RAY Polycarbonate 67 cms Black Hardside...             3,599.00
# 48  Safari RAY Polycarbonate 53 cms Black Hardside...             2,759.00
# 49  FASNO Combo bagpacks, Kids Bag , Plush Bags , ...      229.00 - 459.00
#
#    Rating   Count
# 0     4.0  20,223
# 1     4.0  15,736
# 2     4.1   3,010
# 3     3.9  11,063
# 4     4.3  28,149
# 5     3.6  14,004
# 6     4.0  22,272
# 7     3.9   4,530
# 8     4.1  33,966
# 9     4.3   5,388
# 10    4.4   5,125
# 11    4.0  10,370
# 12    3.9   6,778
# 13    4.1   7,491
# 14    4.1   4,328
# 15    3.8   2,537
# 16    4.3   5,090
# 17    3.7   5,670
# 18    4.2   8,122
# 19    4.0   8,285
# 20    4.6     325
# 21    4.0   4,471
# 22    4.1   6,938
# 23    3.9   2,766
# 24    4.3   2,052
# 25    4.2   5,344
# 26    4.2   3,744
# 27    3.8   4,481
# 28    4.2   2,632
# 29    3.9   1,877
# 30    4.0   5,323
# 31    4.1   1,593
# 32    4.1   1,320
# 33    4.2     532
# 34    4.0   4,158
# 35    4.0     451
# 36    4.4   2,229
# 37    4.3   2,746
# 38    4.0   5,707
# 39    4.1   3,719
# 40    4.1   2,111
# 41    4.5     696
# 42    4.0     381
# 43    4.3     662
# 44    3.9   1,212
# 45    4.0     943
# 46    4.1   6,691
# 47    4.3   4,047
# 48    4.2   2,485
# 49    3.9     715

# %% [markdown]
# We have converted our dataframe into a CSV file so that the file can be used by senior management or people not much familiar with coding.

# %%
df.to_csv('AmazonWebscraping.csv', index = False)

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "bhatnagar91/webscrapingamazon" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/bhatnagar91/webscrapingamazon
# 'https://jovian.ai/bhatnagar91/webscrapingamazon'
